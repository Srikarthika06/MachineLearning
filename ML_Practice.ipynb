# %% [markdown]
# <a href="https://colab.research.google.com/github/Srikarthika06/MachineLearning/blob/main/ML_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("machine learning lab")
# Out:
# machine learning lab
